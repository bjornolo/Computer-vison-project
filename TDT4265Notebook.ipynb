# %%
import os
import shutil
import random 
from tqdm.notebook import tqdm
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
#model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)
model = YOLO(r"runs\detect\train\weights\last.pt")  # load a pretrained model (recommended for training)

# %%
from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

experiment = Experiment(
  api_key = "X9FHxd4dNkM0katQ6En7slpBt"
)

# %%
# Use the model
model.train(data="config.yaml", epochs=5)  # train the model

# %%
metrics = model.val()  # evaluate model performance on the validation set

# %%
success = model.export(format="onnx")  # export the model to ONNX format

# %%
video1_path = r"E:\Lofty\Documents\TDT4265\videos\tdt4265_video1.mp4"
video2_path = r"E:\Lofty\Documents\TDT4265\videos\tdt4265_video2.mp4"
results = model.track(source=video1_path,conf=0.3, iou=0.5, save=True)  # predict on video
results = model.track(source=video2_path,conf=0.3, iou=0.5, save=True)  # predict on video

# %%
experiment.end()
