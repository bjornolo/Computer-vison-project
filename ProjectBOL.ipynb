# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.82-py3-none-any.whl (526 kB)
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#      ------------------------------- ------ 430.1/527.0 kB 9.1 MB/s eta 0:00:01
#      -------------------------------------- 527.0/527.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (1.24.1)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (9.3.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: requests>=2.23.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (2.0.0+cu118)
# Requirement already satisfied: psutil in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (0.15.1+cu118)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------------------------------- 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (3.7.1)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.20.0-py2.py3-none-any.whl (198 kB)
#      ---------------------------------------- 0.0/198.8 kB ? eta -:--:--
#      ------------------------------------- 198.8/198.8 kB 12.6 MB/s eta 0:00:00
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: jinja2 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: filelock in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from torch>=1.7.0->ultralytics) (3.9.0)
# Requirement already satisfied: networkx in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from torch>=1.7.0->ultralytics) (3.0)
# Requirement already satisfied: typing-extensions in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from torch>=1.7.0->ultralytics) (4.4.0)
# Requirement already satisfied: sympy in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from torch>=1.7.0->ultralytics) (1.11.1)
# Requirement already satisfied: colorama in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.2.1)
# Installing collected packages: sentry-sdk, thop, seaborn, ultralytics
# Successfully installed seaborn-0.12.2 sentry-sdk-1.20.0 thop-0.1.1.post2209072238 ultralytics-8.0.82
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import shutil
import random 
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\bonna\pytorchenviorments\torchenv\lib\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.82  Python-3.10.6 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1070, 8192MiB)
# Setup complete  (4 CPUs, 15.9 GB RAM, 328.2/931.5 GB disk)

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="config.yaml", epochs=3)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8m.pt to yolov8m.pt...
# 100%|██████████| 49.7M/49.7M [01:17<00:00, 669kB/s]
# New https://pypi.org/project/ultralytics/8.0.83 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.82  Python-3.10.6 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1070, 8192MiB)
# yolo\engine\trainer: task=detect, mode=train, model=yolov8m.pt, data=config.yaml, epochs=3, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train
# Downloading https:\ultralytics.com\assets\Arial.ttf to C:\Users\bonna\AppData\Roaming\Ultralytics\Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 11.1MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.Conv                  [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.Conv                  [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.C2f                   [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.Conv                  [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.C2f                   [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.Conv                  [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.C2f                   [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.Conv                  [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.C2f                   [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.SPPF                  [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.C2f                   [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  2    517632  ultralytics.nn.modules.C2f                   [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.Conv                  [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.C2f                   [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.Conv                  [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.C2f                   [960, 576, 2]
#  22        [15, 18, 21]  1   3778012  ultralytics.nn.modules.Detect                [4, [192, 384, 576]]
# Model summary: 295 layers, 25858636 parameters, 25858620 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:06<00:00, 967kB/s]
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias
# train: Scanning E:\Lofty\Documents\TDT4265\Data\United_States\train\train\labels... 3844 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3844/3844 [00:12<00:00, 313.22it/s]
# train: New cache created: E:\Lofty\Documents\TDT4265\Data\United_States\train\train\labels.cache
# val: Scanning E:\Lofty\Documents\TDT4265\Data\United_States\train\val\labels... 480 images, 0 backgrounds, 0 corrupt: 100%|██████████| 480/480 [00:02<00:00, 164.90it/s]
# val: New cache created: E:\Lofty\Documents\TDT4265\Data\United_States\train\val\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs\detect\train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3      7.37G      2.044      3.037      1.868         14        640: 100%|██████████| 241/241 [04:44<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:13<00:00,  1.13it/s]
#                    all        480       1098      0.561      0.293      0.271      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3      7.83G      1.708      1.819      1.521         21        640: 100%|██████████| 241/241 [04:40<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:14<00:00,  1.02it/s]
#                    all        480       1098      0.556      0.342      0.304      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3      7.34G      1.655      1.677      1.479         22        640: 100%|██████████| 241/241 [04:41<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:14<00:00,  1.02it/s]
#                    all        480       1098      0.355       0.39      0.358      0.186
#
# 3 epochs completed in 0.250 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 52.0MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 52.0MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics YOLOv8.0.82  Python-3.10.6 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1070, 8192MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:14<00:00,  1.05it/s]
#                    all        480       1098      0.359       0.39      0.358      0.186
#                    D10        480        323      0.415      0.622      0.503      0.239
#                    D00        480        673      0.486       0.64      0.544      0.296
#                    D20        480         84      0.533      0.298      0.374      0.203
#                    D40        480         18          0          0       0.01    0.00348
# Speed: 0.3ms preprocess, 18.4ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs\detect\train
# Ultralytics YOLOv8.0.82  Python-3.10.6 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1070, 8192MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning E:\Lofty\Documents\TDT4265\Data\United_States\train\val\labels.cache... 480 images, 0 backgrounds, 0 corrupt: 100%|██████████| 480/480 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 30/30 [00:15<00:00,  1.94it/s]
#                    all        480       1098      0.356       0.39      0.358      0.185
#                    D10        480        323      0.417      0.622      0.505      0.241
#                    D00        480        673      0.488      0.642      0.544      0.295
#                    D20        480         84      0.521      0.298      0.374      0.202
#                    D40        480         18          0          0     0.0101    0.00361
# Speed: 0.4ms preprocess, 20.1ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs\detect\val
#
# Downloading https:\ultralytics.com\images\bus.jpg to bus.jpg...
# 100%|██████████| 476k/476k [00:00<00:00, 8.89MB/s]
# image 1/1 E:\Lofty\Documents\TDT4265\TDT4265-project\bus.jpg: 640x480 (no detections), 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
success = model.export(format="onnx")  # export the model to ONNX format
#results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# Out:
# Ultralytics YOLOv8.0.82  Python-3.10.6 torch-2.0.0+cu118 CPU
#
# PyTorch: starting from runs\detect\train\weights\best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (49.6 MB)
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success  4.6s, saved as runs\detect\train\weights\best.onnx (98.8 MB)
#
# Export complete (5.9s)
# Results saved to E:\Lofty\Documents\TDT4265\TDT4265-project\runs\detect\train\weights
# Predict:         yolo predict task=detect model=runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train\weights\best.onnx imgsz=640 data=config.yaml
# Visualize:       https://netron.app
